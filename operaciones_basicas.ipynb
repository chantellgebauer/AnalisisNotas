# %% [markdown]
# <a href="https://colab.research.google.com/github/chantellgebauer/AnalisisNotas/blob/main/operaciones_basicas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('ventas.csv')
df.head()
# Out:
#         fecha    producto  precio  unidades
# 0  2024-01-01    Camiseta      20         5
# 1  2024-01-02    Pantalón      30         2
# 2  2024-01-03    Camiseta      20         3
# 3  2024-01-04  Zapatillas      50         1
# 4  2024-01-05    Pantalón      30         4

# %%
df['total'] = df["precio"] * df["unidades"]
df.head()
# Out:
#         fecha    producto  precio  unidades  total
# 0  2024-01-01    Camiseta      20         5    100
# 1  2024-01-02    Pantalón      30         2     60
# 2  2024-01-03    Camiseta      20         3     60
# 3  2024-01-04  Zapatillas      50         1     50
# 4  2024-01-05    Pantalón      30         4    120

# %%
df.groupby("producto")["total"].sum()
# Out:
# producto
# Camiseta      280
# Pantalón      210
# Sudadera      175
# Zapatillas    150
# Name: total, dtype: int64

# %%
df[df["unidades"] > 3]
# Out:
#         fecha  producto  precio  unidades  total
# 0  2024-01-01  Camiseta      20         5    100
# 4  2024-01-05  Pantalón      30         4    120
# 7  2024-01-08  Camiseta      20         6    120

# %%
df["fecha"] = pd.to_datetime(df["fecha"])
df["mes"] = df["fecha"].dt.month
df.head()
# Out:
#        fecha    producto  precio  unidades  total  mes
# 0 2024-01-01    Camiseta      20         5    100    1
# 1 2024-01-02    Pantalón      30         2     60    1
# 2 2024-01-03    Camiseta      20         3     60    1
# 3 2024-01-04  Zapatillas      50         1     50    1
# 4 2024-01-05    Pantalón      30         4    120    1

# %%
df.groupby("mes")["total"].sum()
# Out:
# mes
# 1    815
# Name: total, dtype: int64
